# %% [markdown]
# ### Import Dependencies

# %%
import yfinance as yf 
import pandas as pd 
from pandas import Series,DataFrame
import numpy as np

import datetime
#Visualisation imports
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

#define csv output
output_data = ('../df_csv/us_df.csv')

# %%
# Create list of all companies we want records for. 
US_Stock_list = ['GM', 'F', 'FCAU', 'TSLA' ]
#All_Stock_list = ['VWAGY', 'BAMXF', 'DMLRY', 'POAHY', 'VLVLY','GM', 'F', 'FCAU', 'TSLA'  ]

# Set Range we want to records from. 
start = datetime.date(2019,12,2) 
end = datetime.date(2020,12,3)


# Loop through records for all ticker symbols in our list.
for stock in US_Stock_list:
     globals()[stock] = yf.download(stock,start,end)
#for stock in All_Stock_list:
     #globals()[stock] = yf.download(stock,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
GM.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean    30.043701   30.579134   29.491457   30.018347   29.908212
# std      6.104337    6.063281    6.193110    6.157997    6.072470
# min     16.340000   18.559999   14.330000   16.799999   16.799999
# 25%     25.597500   25.925000   25.012500   25.520000   25.520000
# 50%     29.809999   30.395000   29.335000   29.850000   29.850000
# 75%     34.997500   35.349998   34.417499   34.917499   34.565832
# max     45.910000   46.709999   45.070000   46.459999   46.459999
#
#              Volume
# count  2.540000e+02
# mean   1.501621e+07
# std    6.784169e+06
# min    2.924200e+06
# 25%    9.906700e+06
# 50%    1.431905e+07
# 75%    1.785645e+07
# max    5.200000e+07

# %%
F.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean     7.087835    7.198031    6.960118    7.071811    7.048160
# std      1.451224    1.432067    1.486050    1.463925    1.429831
# min      4.270000    4.420000    3.960000    4.010000    4.010000
# 25%      6.052500    6.112500    5.862500    6.030000    6.030000
# 50%      6.940000    7.050000    6.860000    6.955000    6.955000
# 75%      8.225000    8.345000    8.097500    8.210000    8.210000
# max      9.550000    9.570000    9.440000    9.540000    9.450000
#
#              Volume
# count  2.540000e+02
# mean   7.493850e+07
# std    3.144807e+07
# min    1.188160e+07
# 25%    5.238580e+07
# 50%    6.952290e+07
# 75%    9.234945e+07
# max    2.318008e+08

# %%
FCAU.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean    11.449606   11.559370   11.305157   11.421260   11.032136
# std      2.457999    2.441166    2.484483    2.457146    2.309054
# min      6.180000    6.450000    6.000000    6.350000    5.797826
# 25%      9.710000    9.902500    9.382500    9.655000    9.500870
# 50%     11.600000   11.710000   11.495000   11.525000   11.296739
# 75%     13.295000   13.387500   13.197500   13.267500   12.604348
# max     15.900000   16.040001   15.780000   16.010000   16.010000
#
#              Volume
# count  2.540000e+02
# mean   3.175445e+06
# std    1.800066e+06
# min    9.549000e+05
# 25%    1.930900e+06
# 50%    2.692950e+06
# 75%    3.736200e+06
# max    1.149710e+07

# %%
TSLA.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean   244.012190  250.923449  236.803229  244.311598  244.311598
# std    141.869390  145.355655  137.615670  141.901199  141.901199
# min     65.879997   66.884003   65.449997   66.073997   66.073997
# 25%    126.076002  130.629005  121.775999  128.388000  128.388000
# 50%    181.892998  185.783997  176.055000  180.041000  180.041000
# 75%    394.733498  408.445007  378.302490  402.257500  402.257500
# max    602.210022  607.799988  578.450012  585.760010  585.760010
#
#              Volume
# count  2.540000e+02
# mean   6.342905e+07
# std    4.373405e+07
# min    7.255600e+06
# 25%    3.084645e+07
# 50%    5.664275e+07
# 75%    8.674612e+07
# max    3.046940e+08

# %%
# Add Company columns to all data frames for merge.
GM['Company'] = 'General Motors'
F['Company'] = 'Ford'
FCAU['Company'] = 'Chrysler'
TSLA['Company'] = 'Tesla'


# Create list of manufacturer dataframes to create single dataframe. 
df_list = [GM, F, FCAU, TSLA]

# Create single dataframe with all U.S. manufacturers.
us_df = pd.concat(df_list)

# Add region column to dataframe.
us_df['Region'] = 'U.S.'

# Order Columns
us_df_reordered = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Company', 'Region']

# Display final dataframe
final_us_df = us_df[us_df_reordered]
final_us_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-02   36.009998   36.360001   35.840000   35.880001   35.071316
# 2019-12-03   35.470001   35.619999   34.959999   35.529999   34.729202
# 2019-12-04   35.740002   36.049999   35.680000   35.799999   34.993114
# 2019-12-05   35.599998   35.650002   35.220001   35.310001   34.884445
# 2019-12-06   35.639999   35.759998   35.450001   35.540001   35.111671
# ...                ...         ...         ...         ...         ...
# 2020-11-25  550.059998  574.000000  545.369995  574.000000  574.000000
# 2020-11-27  581.159973  598.780029  578.450012  585.760010  585.760010
# 2020-11-30  602.210022  607.799988  554.510010  567.599976  567.599976
# 2020-12-01  597.590027  597.849976  572.049988  584.760010  584.760010
# 2020-12-02  556.440002  571.539978  541.210022  568.820007  568.820007
#
#               Volume         Company Region
# Date
# 2019-12-02   6782000  General Motors   U.S.
# ...

# %%
fig = plt.figure(figsize=(15,10))
t=GM['Adj Close']
u=GM['Volume']
sub1 = fig.add_subplot(221) 
sub1.set_title('GM Adj Close') 
sub1.plot(t)
sub2 = fig.add_subplot(222)
sub2.set_title('GM Volume')
sub2.plot(u)
sub2.legend(['Volume'])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
t=F['Adj Close']
u=F['Volume']
sub1 = fig.add_subplot(221) 
sub1.set_title('Ford Adj Close') 
sub1.plot(t)
sub2 = fig.add_subplot(222)
sub2.set_title('Ford Volume')
sub2.plot(u)
sub2.legend(['Volume'])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
t=FCAU['Adj Close']
u=FCAU['Volume']
sub1 = fig.add_subplot(221) 
sub1.set_title('Chrysler Adj Close') 
sub1.plot(t)
sub2 = fig.add_subplot(222)
sub2.set_title('Chrysler Volume')
sub2.plot(u)
sub2.legend(['Volume'])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
t=TSLA['Adj Close']
u=TSLA['Volume']
sub1 = fig.add_subplot(221) 
sub1.set_title('Tesla Adj Close') 
sub1.plot(t)
sub2 = fig.add_subplot(222)
sub2.set_title('Tesla Volume')
sub2.plot(u)
sub2.legend(['Volume'])
plt.tight_layout()
plt.show()

# %%
averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    TSLA[label] = TSLA['Adj Close'].rolling(window = avg, center = False).mean()
    F[label] = F['Adj Close'].rolling(window = avg, center = False).mean()
    GM[label] = GM['Adj Close'].rolling(window = avg, center = False).mean()
    FCAU[label] = FCAU['Adj Close'].rolling(window = avg, center = False).mean()

# %%
#TSLA[['Adj Close', 'MAvg for 10 days', 'MAvg for 25 days', 'MAvg for 50 days']].plot(subplots = False, figsize = (10,5))
fig = plt.figure(figsize=(15,10))
C=FCAU[['Adj Close', 'MAvg for 10 days', 'MAvg for 25 days', 'MAvg for 50 days']]
F=F[['Adj Close', 'MAvg for 10 days', 'MAvg for 25 days', 'MAvg for 50 days']]
G=GM[['Adj Close', 'MAvg for 10 days', 'MAvg for 25 days', 'MAvg for 50 days']]
T=TSLA[['Adj Close', 'MAvg for 10 days', 'MAvg for 25 days', 'MAvg for 50 days']]
sub1 = fig.add_subplot(221) 
sub1.set_title('Chrysler') 
sub1.plot(C)
sub2 = fig.add_subplot(222)
sub2.set_title('Ford')
sub2.plot(F)
sub2.legend(['Adj Close'])
sub2.legend(['MAvg for 10 days'])
sub2.legend(['MAvg for 25 days'])
sub2.legend(['MAvg for 50 days'])
sub3 = fig.add_subplot(223) 
sub3.set_title('GM') 
sub3.plot(G)
sub4 = fig.add_subplot(224)
sub4.set_title('Tesla')
sub4.plot(T)
plt.tight_layout()
plt.show()

# %%
TSLA['Daily Return'] = TSLA['Adj Close'].pct_change()
F['Daily Return'] = F['Adj Close'].pct_change()
GM['Daily Return'] = GM['Adj Close'].pct_change()
FCAU['Daily Return'] = FCAU['Adj Close'].pct_change()
# Out:
# <ipython-input-203-93a4d36ca91e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F['Daily Return'] = F['Adj Close'].pct_change()

# %%
close_compr = yf.download(US_Stock_list,start,end)['Adj Close']
rets_compr = close_compr.pct_change()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
sns.distplot(TSLA['Daily Return'].dropna(),bins=100,color='red')

# %%
close_compr = yf.download(US_Stock_list,start,end)['Adj Close']
rets_compr = close_compr.pct_change()
rets_compr.tail()
# Out:
# [*********************100%***********************]  4 of 4 completed
#                    F      FCAU        GM      TSLA
# Date
# 2020-11-25 -0.039153  0.007663 -0.021524  0.033527
# 2020-11-27  0.001101  0.002535 -0.008799  0.020488
# 2020-11-30 -0.001100 -0.020228 -0.027075 -0.031003
# 2020-12-01  0.017621  0.032903  0.019161  0.030233
# 2020-12-02 -0.004329 -0.002498 -0.002238 -0.027259

# %%
corr = rets_compr.corr()
#print(corr)
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, ax = plt.subplots()

# Draw the heatmap with the mask and correct aspect ratio
vmax = np.abs(corr.values[~mask]).max()
sns.heatmap(corr, mask=mask, cmap='coolwarm', vmin=-vmax, vmax=vmax,
            square=True,linecolor="lightgray", linewidths=1, ax=ax)
for i in range(len(corr)):
    ax.text(i+0.5,len(corr)-(i+0.5), corr.columns[i], 
            ha="center", va="center", rotation=45)
    for j in range(i+1, len(corr)):
        s = "{:.3f}".format(corr.values[i,j])
        ax.text(j+0.5,len(corr)-(i+0.5),s, 
            ha="center", va="center")
ax.axis("off")
plt.show()

# %%
rets_filled = rets_compr.dropna()
plt.figure(figsize=(8,5))

plt.scatter(rets_filled.mean(),rets_filled.std(),s=25)

plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label,x,y in zip(rets_filled.columns,rets_filled.mean(),rets_filled.std()):
    plt.annotate(
    label,
    xy=(x,y),xytext=(-10,5),
    textcoords = 'offset points',
    arrowprops = dict(arrowstyle='->',connectionstyle = 'arc3,rad=-0.8'))
