# %%
# Get all open, close, max, min, and volume for all major Asian car manufacturers for that last 2 years
import yfinance as yf
import csv
import pandas as pd

# %%
# Nissan
nissan = yf.Ticker("NSANY")
hist = nissan.history(period)

# %%
# Honda
data = yf.download("NSANY HMC TM HYMTF", start="2019-01-01", end="2020-12-31").reset_index()
print(data)
# Out:
# [*********************100%***********************]  4 of 4 completed
#           Date  Adj Close                                        Close  \
#                       HMC      HYMTF      NSANY          TM        HMC
# 0   2019-01-02  25.102514  24.902649  15.383476  112.735107  26.480000
# 1   2019-01-03  24.761240  24.902649  15.364342  111.154800  26.120001
# 2   2019-01-04  25.889338  24.902649  15.651348  116.079933  27.309999
# 3   2019-01-07  26.372807  24.902649  15.813984  117.582680  27.820000
# 4   2019-01-08  26.998472  24.902649  15.794851  118.581276  28.480000
# ..         ...        ...        ...        ...         ...        ...
# 481 2020-11-27  28.750000  38.700001  10.000000  140.160004  28.750000
# 482 2020-11-30  27.719999  38.500000   9.420000  134.460007  27.719999
# 483 2020-12-01  28.360001  38.500000   9.720000  136.139999  28.360001
# 484 2020-12-02  29.129999  39.799999   9.850000  136.339996  29.129999
# ...

# %%
# Toyota 
data.to_csv(r'./asia.csv',index=False, header=True)

# %%
# Hyundai

# %%
# Kia
